# %% [markdown]
# <a href="https://colab.research.google.com/github/faajr/instacart/blob/main/instacart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IMPORT DATA FROM KAGGELS

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "postgresql+psycopg2://my-first-postgres-service-84fd3552.pg1dz3pskr6e7nnq6gt36faq4g.c0.ap-northeast-1.aws.pg.clickhouse.cloud:5432/postgres"
)

# %%
# !pip install kagglehub[pandas-datasets]

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = "aisles.csv"

# Load the latest version
aisles= kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "psparks/instacart-market-basket-analysis",
  file_path
)

print("First 100000 records:", aisles.head())
# Out:
# /tmp/ipykernel_2990/764325058.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   aisles= kagglehub.load_dataset(
# ...
# 100%|██████████| 2.54k/2.54k [00:00<00:00, 4.61MB/s]
# First 100000 records:    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = "departments.csv"

# Load the latest version
departments= kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "psparks/instacart-market-basket-analysis",
  file_path
)

print("First 100000 records:", departments.head())
# Out:
# /tmp/ipykernel_2990/2281540585.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   departments= kagglehub.load_dataset(
# Using Colab cache for faster access to the 'instacart-market-basket-analysis' dataset.
# First 100000 records:    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = "products.csv"

# Load the latest version
products= kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "psparks/instacart-market-basket-analysis",
  file_path
)

print("First 100000 records:", products.head())
# Out:
# /tmp/ipykernel_2990/1472860276.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   products= kagglehub.load_dataset(
# Using Colab cache for faster access to the 'instacart-market-basket-analysis' dataset.
# First 100000 records:    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = "orders.csv"

# Load the latest version
orders= kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "psparks/instacart-market-basket-analysis",
  file_path
)

print("First 100000 records:", orders.head())
# Out:
# /tmp/ipykernel_2990/3200857496.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   orders= kagglehub.load_dataset(
# Using Colab cache for faster access to the 'instacart-market-basket-analysis' dataset.
# First 100000 records:    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
# Set the path to the file you'd like to load
file_path = "order_products__train.csv"

# Load the latest version
order_products= kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "psparks/instacart-market-basket-analysis",
  file_path
)

print("First 100000 records:", order_products.head())
# Out:
# /tmp/ipykernel_2990/2470290730.py:7: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   order_products= kagglehub.load_dataset(
# Using Colab cache for faster access to the 'instacart-market-basket-analysis' dataset.
# First 100000 records:    order_id  product_id  add_to_cart_order  reordered
# 0         1       49302                  1          1
# 1         1       11109                  2          1
# 2         1       10246                  3          0
# 3         1       49683                  4          0
# 4         1       43633                  5          1

# %% [markdown]
# # Cek Duplikat

# %%
aisles.duplicated ().sum()
# Out:
# np.int64(0)

# %%
departments.duplicated ().sum()
# Out:
# np.int64(0)

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %%
order_products.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Cek Missing Value

# %%
aisles.isnull().sum()
# Out:
# aisle_id    0
# aisle       0
# dtype: int64

# %%
departments.isnull().sum()
# Out:
# department_id    0
# department       0
# dtype: int64

# %%
orders.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# order_dow                      0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
products.isnull().sum()
# Out:
# product_id       0
# product_name     0
# aisle_id         0
# department_id    0
# dtype: int64

# %%
order_products.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %% [markdown]
# # Import Data

# %%
pip install sqlalchemy psycopg2-binary

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

DATABASE_URL = (
    "postgresql+psycopg2://postgres:Sct4otc_WeEmQL6pUo23@"
    "my-first-postgres-service-84fd3552.pg1dz3pskr6e7nnq6gt36faq4g.c0.ap-northeast-1.aws.pg.clickhouse.cloud:5432/postgres"
)

engine = create_engine(DATABASE_URL)

# %%
aisles.to_sql("aisles",engine,if_exists="replace",index=False)
# Out:
# 134

# %%
departments.to_sql("departments",engine,if_exists="replace",index=False)
# Out:
# 21

# %%
products.to_sql("products",engine,if_exists="replace",index=False)
# Out:
# 688

# %%
orders.to_sql("orders",engine,if_exists="replace",index=False)
# Out:
# 83

# %%
order_products.to_sql("order_products",engine,if_exists="replace",index=False)
# Out:
# 617

# %% [markdown]
# # IMPORT DATAFIX

# %%
import psycopg2

conn = psycopg2.connect(
    host="my-first-postgres-service-84fd3552.pg1dz3pskr6e7nnq6gt36faq4g.c0.ap-northeast-1.aws.pg.clickhouse.cloud",
    port="5432",
    database="postgres",
    user="postgres",
    password="Sct4otc_WeEmQL6pUo23"
)

# %%
query = "SELECT * FROM datafix"
df = pd.read_sql(query, conn)
# Out:
# /tmp/ipykernel_2990/1570798826.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn)

# %%
df.to_csv('datafix.csv', index=False)

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2920 entries, 0 to 2919
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                2920 non-null   int64
#  1   user_id                 2920 non-null   int64
#  2   eval_set                2920 non-null   object
#  3   order_number            2920 non-null   int64
#  4   order_dow               2920 non-null   int64
#  5   order_hour_of_day       2920 non-null   int64
#  6   days_since_prior_order  2920 non-null   float64
#  7   product_id              2920 non-null   int64
#  8   add_to_cart_order       2920 non-null   int64
#  9   reordered               2920 non-null   int64
#  10  product_name            2920 non-null   object
#  11  aisle_id                2920 non-null   int64
#  12  aisle                   2920 non-null   object
#  13  department_id           2920 non-null   int64
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine

# %% [markdown]
# # 1. Hari Paling Sibuk — Bar Chart
# Tujuan: Mengetahui hari dengan jumlah order terbanyak sehingga perusahaan bisa menentukan waktu terbaik untuk promosi, stok barang, dan penjadwalan operasional.

# %%
import matplotlib.pyplot as plt

# Menghitung jumlah order per hari
busy_day = df['order_dow'].value_counts().sort_index()

# Membuat visualisasi
plt.figure(figsize=(8,5))

sns.barplot(
    x=busy_day.index,
    y=busy_day.values
)

# Judul dan label
plt.title("Hari Paling Sibuk")
plt.xlabel("Hari")
plt.ylabel("Jumlah Order")

# Optional: ganti angka jadi nama hari
plt.xticks(
    ticks=range(7),
    labels=['Minggu','Senin','Selasa','Rabu','Kamis','Jumat','Sabtu']
)

plt.show()

# %% [markdown]
# # Insight
# *   Hari 0 (Minggu) memiliki transaksi tertinggi.
# *   Banyak pelanggan berbelanja saat akhir pekan.
#
# Rekomendasi
# *   Tambah stok menjelang akhir pekan.
# *   Jalankan promo weekend.

# %% [markdown]
# # 2. Rata-rata Customer Melakukan Re-order — Histogram
# Tujuan: Melihat distribusi rata-rata reorder customer untuk memahami loyalitas pelanggan dan kebiasaan repeat order.

# %%
import matplotlib.pyplot as plt

customer_reorder = df.groupby('user_id')['reordered'].mean()

plt.figure(figsize=(8,5))
plt.hist(customer_reorder, bins=20)

mean_reorder = customer_reorder.mean()

plt.axvline(
    mean_reorder,
    linestyle='--',
    linewidth=2,
    label=f'Rata-rata = {mean_reorder:.2f}'
)

plt.title('Rata-rata Customer Melakukan Re-order')
plt.xlabel('Reorder Rate')
plt.ylabel('Jumlah Customer')
plt.legend()

plt.show()

# %% [markdown]
# # Insight
#  *   Jika mayoritas customer berada di rentang 0.6–0.8, berarti banyak pelanggan yang sering membeli ulang produk yang sama.
# *   Jika mayoritas berada di rentang 0–0.3, berarti pelanggan cenderung mencoba produk baru dan loyalitas masih rendah.

# %% [markdown]
# # 3. Produk Organik vs Non Organik — Pie Chart
# Tujuan: Mengetahui minat customer terhadap produk organik dibanding non-organik untuk membantu strategi produk dan pemasaran.

# %%
import matplotlib.pyplot as plt

#memisahkan produk organik dan non organik
organic = df[
    df['product_name']
    .str.contains('Organic', case=False, na=False)
]

non_organic = df[
    ~df['product_name']
    .str.contains('Organic', case=False, na=False)
]

# Jumlah perbandingan organik dan non organik pie chart
labels = ['Organic', 'Non-Organic']
sizes = [len(organic), len(non_organic)]

# Plot
plt.figure(figsize=(7,7))

plt.pie(
    sizes,
    labels=labels,
    autopct='%1.1f%%'
)

plt.title("Organic vs Non-Organic Products")

plt.show()

# %% [markdown]
# # Insight
# *   Jika Non Organic mendominasi, berarti mayoritas pelanggan masih memilih produk reguler.
# *   Jika Organic memiliki persentase tinggi, menunjukkan adanya minat besar terhadap produk sehat dan premium.

# %% [markdown]
# # 4. Customer Activity Timeline — Line Chart
# Tujuan: Melihat pola aktivitas customer berdasarkan jam belanja untuk menentukan prime time transaksi.

# %%
import matplotlib.pyplot as plt

# Jumlah order unik per jam
timeline = (
    df.groupby('order_hour_of_day')['order_id']
      .nunique()
      .sort_index()
)

plt.figure(figsize=(14, 5))

# Line chart
plt.plot(
    timeline.index,
    timeline.values,
    marker='o',
    linestyle='-',
    linewidth=2,
    color='green'
)

# Menampilkan nilai di setiap titik
for x, y in zip(timeline.index, timeline.values):
    plt.text(
        x,
        y + 5,
        str(y),
        ha='center',
        fontsize=8
    )

plt.title("Customer Activity Timeline")
plt.xlabel("Hour of Day")
plt.ylabel("Number of Orders")

plt.xticks(range(24))
plt.grid(True, linestyle='--', alpha=0.6)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insight
# Aktivitas pembelian seiring bertambahnya order pelanggan

# %% [markdown]
# # 5. Jam Paling Ramai — Bar Chart
# Tujuan: Mengetahui jam dengan traffic order tertinggi agar perusahaan dapat mengoptimalkan server, pengiriman, dan promosi.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

jam_ramai = (
    df.groupby('order_hour_of_day')['order_id']
      .nunique()
      .reset_index(name='total_orders')
)

peak_hour = jam_ramai['total_orders'].idxmax()

colors = ['tab:blue'] * len(jam_ramai)
colors[peak_hour] = 'tab:red'

plt.figure(figsize=(12,6))

ax = sns.barplot(
    data=jam_ramai,
    x='order_hour_of_day',
    y='total_orders',
    palette=colors
)

for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=3)

plt.title('Jam Paling Ramai Berdasarkan Jumlah Order', fontsize=14, fontweight='bold')
plt.xlabel('Jam')
plt.ylabel('Jumlah Order')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_2990/504741817.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %% [markdown]
# # Insight
# * Puncak transaksi pukul 12.00.
#
# Rekomendasi
# * Tingkatkan kapasitas sistem dan stok pada jam tersebut.

# %% [markdown]
# # 6. 10 Produk Terlaris — Bar Chart Vertikal
# Tujuan: Mengetahui produk paling sering dibeli untuk strategi stok, bundling, dan promosi.

# %%
# Top 10 produk berdasarkan jumlah pembelian
top_produk = (
    df.groupby('product_name')['order_id']
      .count()
      .sort_values(ascending=False)
      .head(10)
      .reset_index(name='total_pembelian')
)

# Style
sns.set_style("whitegrid")

plt.figure(figsize=(12, 6))

ax = sns.barplot(
    data=top_produk,
    x='product_name',
    y='total_pembelian'
)

# Label nilai di atas bar
for container in ax.containers:
    ax.bar_label(container, fmt='%d', padding=3, fontsize=9)

plt.title('10 Produk Terlaris', fontsize=14, fontweight='bold')
plt.xlabel('Nama Produk')
plt.ylabel('Jumlah Pembelian')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insight
# * Banana menjadi produk paling laris.
#
# Rekomendasi
# * Prioritaskan stok produk tersebut.

# %% [markdown]
# # 7. Reorder vs Non Reorder — Bar cart
# Tujuan: Melihat perbandingan jumlah produk yang di-reorder dan tidak untuk memahami customer retention.

# %%
df['reorder_status'] = df['reordered'].map({
    0: 'Non Reorder',
    1: 'Reorder'
})

plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x='reorder_status'
)

for container in ax.containers:
    ax.bar_label(container)

plt.title('Reorder vs Non Reorder')
plt.xlabel('Status Pembelian')
plt.ylabel('Jumlah Produk')

plt.show()

# %% [markdown]
# # Insight
# * Sebagian besar produk dibeli ulang.
#
# Rekomendasi
# * Buat loyalty program.

# %% [markdown]
# # 8. Hubungan Barang Dimasukkan dan Barang Re-order
# Tujuan: Menganalisis apakah urutan produk dimasukkan ke keranjang mempengaruhi kemungkinan produk di-reorder.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

cart_reorder = (
    df.groupby('add_to_cart_order')['reordered']
      .mean()
      .reset_index()
)

plt.figure(figsize=(12, 6))

sns.scatterplot(
    data=cart_reorder,
    x='add_to_cart_order',
    y='reordered'
)

plt.title('Peluang Reorder Berdasarkan Urutan Produk dalam Keranjang',
          fontsize=14, fontweight='bold')
plt.xlabel('Urutan Produk Ditambahkan ke Keranjang')
plt.ylabel('Rata-rata Reorder')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Insight
# * Produk yang masuk lebih awal cenderung sering direorder.
#
# Rekomendasi
# * Gunakan sebagai dasar sistem rekomendasi.
